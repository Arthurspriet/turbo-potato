# %%
import pandas as pd 
import re

# %%
Celeb = pd.read_csv('/Users/arthurspriet/Desktop/Top 1000 celebrity twitter accounts/Top-1000-Celebrity-Twitter-Accounts.csv')

# %%
Celeb['name'] = Celeb['name'].str.lower()
Celeb.reset_index()
# Out:
#      index          twitter                               domain  \
# 0        0        katyperry                        katyperry.com
# 1        1     justinbieber                          smarturl.it
# 2        2    taylorswift13                           grmypro.co
# 3        3          rihanna                       rihannanow.com
# 4        4         ladygaga                                  NaN
# ..     ...              ...                                  ...
# 991    991             Zedd                          smarturl.it
# 992    992  SleepintheGardn  katuriankaturiankaturian.tumblr.com
# 993    993    therealjuicyj                        thejuicyj.com
# 994    994      manugavassi                   manugavassi.com.br
# 995    995         soujorge                         seujorge.com
#
#               name       type
# 0       katy perry  celebrity
# 1    justin bieber  celebrity
# 2     taylor swift  celebrity
# 3          rihanna  celebrity
# 4     the countess  celebrity
# ..             ...        ...
# 991           zedd  celebrity
# 992         troian  celebrity
# 993        juicy j  celebrity
# 994   manu gavassi  celebrity
# 995      seu jorge  celebrity
#
# [996 rows x 5 columns]

# %%
Celeb = Celeb[['name','twitter']]
Celeb
# Out:
#               name          twitter
# 0       katy perry        katyperry
# 1    justin bieber     justinbieber
# 2     taylor swift    taylorswift13
# 3          rihanna          rihanna
# 4     the countess         ladygaga
# ..             ...              ...
# 991           zedd             Zedd
# 992         troian  SleepintheGardn
# 993        juicy j    therealjuicyj
# 994   manu gavassi      manugavassi
# 995      seu jorge         soujorge
#
# [996 rows x 2 columns]

# %%
Celeb
# Out:
#               name          twitter
# 0       katy perry        katyperry
# 1    justin bieber     justinbieber
# 2     taylor swift    taylorswift13
# 3          rihanna          rihanna
# 4     the countess         ladygaga
# ..             ...              ...
# 991           zedd             Zedd
# 992         troian  SleepintheGardn
# 993        juicy j    therealjuicyj
# 994   manu gavassi      manugavassi
# 995      seu jorge         soujorge
#
# [996 rows x 2 columns]

# %%
def find_account ():
    search = input('enter a famous name')
    for name in Celeb['name'] :
        if name == search :
            x =
# Out:
#   File "/var/folders/bx/4mbq6kdx7yq1jqkn_7345mqc0000gn/T/ipykernel_11478/3098104851.py", line 5
#     x =
#         ^
# SyntaxError: invalid syntax

# %%
filter1 = Celeb['name']== 'taylor swift'
account = Celeb.where(filter1, inplace = True)

print(account)

# %%
Celeb
# Out:
#           name   twitter
# 765  elon musk  elonmusk

# %%
def find_account () :
    celeb = Celeb.copy()
    person = input('please enter a person ')
    person = person.lower()
    filter1 = Celeb['name']== person
    x = celeb.where(filter1,inplace = True)
    x = celeb.dropna(subset = ["twitter"], inplace=True)
    x = celeb['twitter']
    x = str(x)
    x = re.findall('[A-z]+',x)
    x = x[0]
    return x

# %%
find_account()
# Out:
# please enter a person elon musk
# 'elonmusk'

# %%
Celeb
# Out:
#               name          twitter
# 0       katy perry        katyperry
# 1    justin bieber     justinbieber
# 2     taylor swift    taylorswift13
# 3          rihanna          rihanna
# 4     the countess         ladygaga
# ..             ...              ...
# 991           zedd             Zedd
# 992         troian  SleepintheGardn
# 993        juicy j    therealjuicyj
# 994   manu gavassi      manugavassi
# 995      seu jorge         soujorge
#
# [996 rows x 2 columns]
